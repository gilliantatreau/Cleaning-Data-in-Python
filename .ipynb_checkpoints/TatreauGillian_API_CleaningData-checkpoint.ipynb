# %% [markdown]
# # Cleaning Data from API Pull
# # Gillian Tatreau
# # February 2023
# ### Most current API pull: 26 February 2024

# %%
# import libraries
from itertools import repeat
import requests
import urllib.request, urllib.parse
from urllib.error import HTTPError,URLError
import json
import pandas as pd

# if using jupyter notebook, to import config file if saved in .ipynb file
# import import_ipynb

# file with secret key
import config

# %%
def get_list_of_lists():
    """
    Function to get list of best seller's lists
    """
    
    url = 'https://api.nytimes.com/svc/books/v3/lists/names.json?api-key='+config.my_key
    # checking connection
    try: 
        uh = urllib.request.urlopen(url)
    except HTTPError as e:
        print("Sorry! Could not retrive anything")
        return None
    except URLError as e:
        print('Failed to reach a server.')
        print('Reason: ', e.reason)
        return None
    else:
        data = uh.read().decode()
        print("Retrieved data. Total {} characters read.".format(len(data)))
    x = json.loads(data)
    y = x['results']
    return y

# %%
def get_list_data(l):
    """
    Function to get data from each bestseller's list in list_of_lists
    """
    list_name = str(l)
    url = 'https://api.nytimes.com/svc/books/v3/lists/current/'+list_name+'.json?api-key='+config.my_key
    # checking connection
    try: 
        uh = urllib.request.urlopen(url)
    except HTTPError as e:
        print("Sorry! Could not retrive anything on {}".format(list_name))
        return None
    except URLError as e:
        print('Failed to reach a server.')
        print('Reason: ', e.reason)
        return None
    else:
        data = uh.read().decode()
        print("Retrieved data on {}. Total {} characters read.".format(list_name,len(data)))
        return data

# %%
def build_list_dataBase(partial_list):
    """
    Function to create pandas DataFrame from bestseller's lists data. 
    Due to the number of calls needed for the number of bestseller's lists, the function must be called multiple times, 
    each with a subset of the list_of_lists.
    """
    list_dict = {'bestsellers_date':[],'bestsellers_list':[],'rank':[],'rank_last_week':[],'weeks_on_list':[],
                  'isbn10':[],'isbn13':[],'publisher':[],'title':[],'author':[],
                  'contributor':[]}
    
    for l in partial_list:
        data = get_list_data(l)
        if data !=None:
            x = json.loads(data)
            y = x["results"]
            z = y["books"]
            list_dict['bestsellers_date'].extend(repeat(y['bestsellers_date'],len(z)))
            list_dict['bestsellers_list'].extend(repeat(y['list_name'],len(z)))
            for i in z:
                list_dict['rank'].append(i['rank'])
                list_dict['rank_last_week'].append(i['rank_last_week'])
                list_dict['weeks_on_list'].append(i['weeks_on_list'])
                list_dict['isbn10'].append(i['primary_isbn10'])
                list_dict['isbn13'].append(i['primary_isbn13'])
                list_dict['publisher'].append(i['publisher'])
                list_dict['title'].append(i['title'])
                list_dict['author'].append(i['author'])
                list_dict['contributor'].append(i['contributor'])
    
    return pd.DataFrame(list_dict)

# %%
# create list_of_lists
a = get_list_of_lists()
list_of_lists = []
for i in a:
    list_of_lists.append(i["list_name_encoded"])
len(a)
# Out:
# Retrieved data. Total 12486 characters read.
# 59

# %%
# breaking up list_of_lists into sublists that the API will be able to handle
a1 = list_of_lists[:5]
a2 = list_of_lists[5:10]
a3 = list_of_lists[10:15]
a4 = list_of_lists[15:20]
a5 = list_of_lists[20:25]
a6 = list_of_lists[25:30]
a7 = list_of_lists[30:35]
a8 = list_of_lists[35:40]
a9 = list_of_lists[40:45]
a10 = list_of_lists[45:50]
a11 = list_of_lists[50:55]
a12 = list_of_lists[55:]

# %%
# call function to perform API calls and convert data to first pandas DataFrame
df1 = build_list_dataBase(a1)
# Out:
# Retrieved data on combined-print-and-e-book-fiction. Total 25069 characters read.
# Retrieved data on combined-print-and-e-book-nonfiction. Total 26541 characters read.
# Retrieved data on hardcover-fiction. Total 25241 characters read.
# Retrieved data on hardcover-nonfiction. Total 24986 characters read.
# Retrieved data on trade-fiction-paperback. Total 25410 characters read.

# %%
# each call must be about a minute apart
df2 = build_list_dataBase(a2)
# Out:
# Retrieved data on mass-market-paperback. Total 27106 characters read.
# Retrieved data on paperback-nonfiction. Total 27095 characters read.
# Retrieved data on e-book-fiction. Total 26128 characters read.
# Retrieved data on e-book-nonfiction. Total 28302 characters read.
# Retrieved data on hardcover-advice. Total 25369 characters read.

# %%
df3 = build_list_dataBase(a3)
# Out:
# Retrieved data on paperback-advice. Total 26084 characters read.
# Retrieved data on advice-how-to-and-miscellaneous. Total 16385 characters read.
# Retrieved data on hardcover-graphic-books. Total 17561 characters read.
# Retrieved data on paperback-graphic-books. Total 17830 characters read.
# Retrieved data on manga. Total 17158 characters read.

# %%
df4 = build_list_dataBase(a4)
# Out:
# Retrieved data on combined-print-fiction. Total 37762 characters read.
# Retrieved data on combined-print-nonfiction. Total 37681 characters read.
# Retrieved data on chapter-books. Total 17313 characters read.
# Retrieved data on childrens-middle-grade. Total 25759 characters read.
# Retrieved data on childrens-middle-grade-e-book. Total 8497 characters read.

# %%
df5 = build_list_dataBase(a5)
# Out:
# Retrieved data on childrens-middle-grade-hardcover. Total 16942 characters read.
# Retrieved data on childrens-middle-grade-paperback. Total 17154 characters read.
# Retrieved data on paperback-books. Total 18320 characters read.
# Retrieved data on picture-books. Total 16399 characters read.
# Retrieved data on series-books. Total 36798 characters read.

# %%
df6 = build_list_dataBase(a6)
# Out:
# Retrieved data on young-adult. Total 26865 characters read.
# Retrieved data on young-adult-e-book. Total 8081 characters read.
# Retrieved data on young-adult-hardcover. Total 15779 characters read.
# Retrieved data on young-adult-paperback. Total 17381 characters read.
# Retrieved data on animals. Total 17693 characters read.

# %%
df7 = build_list_dataBase(a7)
# Out:
# Retrieved data on audio-fiction. Total 26539 characters read.
# Retrieved data on audio-nonfiction. Total 27811 characters read.
# Retrieved data on business-books. Total 16491 characters read.
# Retrieved data on celebrities. Total 18336 characters read.
# Retrieved data on crime-and-punishment. Total 19205 characters read.

# %%
df8 = build_list_dataBase(a8)
# Out:
# Retrieved data on culture. Total 18252 characters read.
# Retrieved data on education. Total 18347 characters read.
# Retrieved data on espionage. Total 18008 characters read.
# Retrieved data on expeditions-disasters-and-adventures. Total 19508 characters read.
# Retrieved data on fashion-manners-and-customs. Total 17844 characters read.

# %%
df9 = build_list_dataBase(a9)
# Out:
# Retrieved data on food-and-fitness. Total 17455 characters read.
# Retrieved data on games-and-activities. Total 17446 characters read.
# Retrieved data on graphic-books-and-manga. Total 24891 characters read.
# Retrieved data on hardcover-business-books. Total 25793 characters read.
# Retrieved data on health. Total 18309 characters read.

# %%
df10 = build_list_dataBase(a10)
# Out:
# Retrieved data on humor. Total 17937 characters read.
# Retrieved data on indigenous-americans. Total 9606 characters read.
# Retrieved data on relationships. Total 18811 characters read.
# Retrieved data on mass-market-monthly. Total 26753 characters read.
# Retrieved data on middle-grade-paperback-monthly. Total 17185 characters read.

# %%
df11 = build_list_dataBase(a11)
# Out:
# Retrieved data on paperback-business-books. Total 19571 characters read.
# Retrieved data on family. Total 17940 characters read.
# Retrieved data on hardcover-political-books. Total 19215 characters read.
# Retrieved data on race-and-civil-rights. Total 19008 characters read.
# Retrieved data on religion-spirituality-and-faith. Total 17662 characters read.

# %%
df12 = build_list_dataBase(a12)
# Out:
# Retrieved data on science. Total 18928 characters read.
# Retrieved data on sports. Total 17207 characters read.
# Retrieved data on travel. Total 18236 characters read.
# Retrieved data on young-adult-paperback-monthly. Total 16324 characters read.

# %% [markdown]
# ## Step 1
# Combining all 7 DataFrames into 1 consolidated DataFrame

# %%
df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12]

# %%
df = pd.concat(df_list, ignore_index=True)

# %%
df
# Out:
#     bestsellers_date                   bestsellers_list  rank  rank_last_week  \
# 0         2024-02-17  Combined Print and E-Book Fiction     1               1
# 1         2024-02-17  Combined Print and E-Book Fiction     2               5
# 2         2024-02-17  Combined Print and E-Book Fiction     3               4
# 3         2024-02-17  Combined Print and E-Book Fiction     4               6
# 4         2024-02-17  Combined Print and E-Book Fiction     5               3
# ..               ...                                ...   ...             ...
# 680       2024-02-03      Young Adult Paperback Monthly     6               0
# 681       2024-02-03      Young Adult Paperback Monthly     7               0
# 682       2024-02-03      Young Adult Paperback Monthly     8               0
# 683       2024-02-03      Young Adult Paperback Monthly     9               0
# 684       2024-02-03      Young Adult Paperback Monthly    10               0
#
#      weeks_on_list      isbn10         isbn13         publisher  \
# 0                2  1250178630  9781250178633      St. Martin's
# 1               42  1649374046  9781649374042         Red Tower
# 2                2  0593550404  9780593550403           Berkley
# 3               15  1649374178  9781649374172         Red Tower
# 4                3  1635574102  9781635574104        Bloomsbury
# ..             ...         ...            ...               ...
# 680              0  0593619919  9780593619919            Putnam
# 681              0  1419760874  9781419760877            Amulet
# 682              0              9781665951388  Simon & Schuster
# 683              0  1728205476  9781728205472  Sourcebooks Fire
# 684              0  0375842209  9780375842207             Knopf
#
#                             title          author        contributor
# 0                       THE WOMEN  Kristin Hannah  by Kristin Hannah
# 1                     FOURTH WING  Rebecca Yarros  by Rebecca Yarros
# 2                           BRIDE   Ali Hazelwood   by Ali Hazelwood
# 3                      IRON FLAME  Rebecca Yarros  by Rebecca Yarros
# 4       HOUSE OF FLAME AND SHADOW   Sarah J. Maas   by Sarah J. Maas
# ..                            ...             ...                ...
# 680                  CHECK & MATE   Ali Hazelwood   by Ali Hazelwood
# 681                     LIGHTLARK      Alex Aster      by Alex Aster
# 682                   THE DO-OVER    Lynn Painter    by Lynn Painter
# 683  MY LIFE WITH THE WALTER BOYS       Ali Novak       by Ali Novak
# 684                THE BOOK THIEF    Markus Zusak    by Markus Zusak
#
# [685 rows x 11 columns]

# %% [markdown]
# ## Step 2
# Check for outliers, unique values, number of NAs, and data types for each column.

# %%
# exploring datatypes of each column
df.dtypes
# Out:
# bestsellers_date    object
# bestsellers_list    object
# rank                 int64
# rank_last_week       int64
# weeks_on_list        int64
# isbn10              object
# isbn13              object
# publisher           object
# title               object
# author              object
# contributor         object
# dtype: object

# %%
# number of unique values
df.nunique()
# Out:
# bestsellers_date     11
# bestsellers_list     59
# rank                 20
# rank_last_week       16
# weeks_on_list       102
# isbn10              549
# isbn13              591
# publisher           223
# title               545
# author              477
# contributor         480
# dtype: int64

# %%
duplicate = df[df.duplicated('title')]
duplicate.head(60)
# Out:
#     bestsellers_date                  bestsellers_list  rank  rank_last_week  \
# 30        2024-02-17                 Hardcover Fiction     1               1
# 31        2024-02-17                 Hardcover Fiction     2               3
# 32        2024-02-17                 Hardcover Fiction     3               4
# 33        2024-02-17                 Hardcover Fiction     4               2
# 34        2024-02-17                 Hardcover Fiction     5               5
# 35        2024-02-17                 Hardcover Fiction     6               6
# 36        2024-02-17                 Hardcover Fiction     7               0
# 45        2024-02-17              Hardcover Nonfiction     1               2
# 46        2024-02-17              Hardcover Nonfiction     2               3
# 47        2024-02-17              Hardcover Nonfiction     3               1
# 48        2024-02-17              Hardcover Nonfiction     4               4
# 49        2024-02-17              Hardcover Nonfiction     5               0
# 53        2024-02-17              Hardcover Nonfiction     9               0
# 54        2024-02-17              Hardcover Nonfiction    10               8
# 60        2024-02-17           Trade Fiction Paperback     1               1
# 61        2024-02-17           Trade Fiction Paperback     2               2
# 62        2024-02-17           Trade Fiction Paperback     3               4
# 63        2024-02-17           Trade Fiction Paperback     4               3
# 64        2024-02-17           Trade Fiction Paperback     5               7
# 66        2024-02-17           Trade Fiction Paperback     7               6
# 68        2024-02-17           Trade Fiction Paperback     9               0
# 90        2024-02-17              Paperback Nonfiction     1               1
# 91        2024-02-17              Paperback Nonfiction     2               2
# 92        2024-02-17              Paperback Nonfiction     3               3
# 93        2024-02-17              Paperback Nonfiction     4               4
# 94        2024-02-17              Paperback Nonfiction     5               5
# 95        2024-02-17              Paperback Nonfiction     6               6
# 97        2024-02-17              Paperback Nonfiction     8               7
# 100       2024-02-17              Paperback Nonfiction    11               8
# 118       2017-01-14                    E-Book Fiction    14               0
# 133       2017-01-14                 E-Book Nonfiction    14               0
# 242       2013-04-27         Combined Print Nonfiction    18               0
# 256       2015-08-08            Childrens Middle Grade     2               0
# 271       2017-01-14     Childrens Middle Grade E-Book     2               5
# 279       2024-02-17  Childrens Middle Grade Hardcover     5               3
# 285       2017-01-14  Childrens Middle Grade Paperback     1               1
# 286       2017-01-14  Childrens Middle Grade Paperback     2               2
# 287       2017-01-14  Childrens Middle Grade Paperback     3               3
# 290       2017-01-14  Childrens Middle Grade Paperback     6               8
# 294       2017-01-14  Childrens Middle Grade Paperback    10               4
# 304       2012-11-24                   Paperback Books    10               0
# 326       2015-08-08                       Young Adult     2               0
# 328       2015-08-08                       Young Adult     4               0
# 330       2015-08-08                       Young Adult     6               0
# 331       2015-08-08                       Young Adult     7               0
# 334       2015-08-08                       Young Adult    10               0
# 355       2017-01-14             Young Adult Paperback     1               3
# 378                                  by Rebecca Yarros
# 379                                   by James McBride
# 380                                    by Ann Patchett
# 382                                   by Sarah J. Maas
# 383                                 by Shelby Van Pelt
# 384                                   by Bonnie Garmus
# 385                                   by Sarah J. Maas

# %%
# number of NAs in each column
df.isna().sum()
# Out:
# bestsellers_date    0
# bestsellers_list    0
# rank                0
# rank_last_week      0
# weeks_on_list       0
# isbn10              0
# isbn13              0
# publisher           0
# title               0
# author              0
# contributor         0
# dtype: int64

# %% [markdown]
# ## Step 3
# Change all strings in DataFrame to lowercase.

# %%
# make all strings lowercase
df = df.applymap(lambda s: s.lower() if type(s) == str else s)

# %%
df.head()
# Out:
#   bestsellers_date                   bestsellers_list  rank  rank_last_week  \
# 0       2024-02-17  combined print and e-book fiction     1               1
# 1       2024-02-17  combined print and e-book fiction     2               5
# 2       2024-02-17  combined print and e-book fiction     3               4
# 3       2024-02-17  combined print and e-book fiction     4               6
# 4       2024-02-17  combined print and e-book fiction     5               3
#
#    weeks_on_list      isbn10         isbn13     publisher  \
# 0              2  1250178630  9781250178633  st. martin's
# 1             42  1649374046  9781649374042     red tower
# 2              2  0593550404  9780593550403       berkley
# 3             15  1649374178  9781649374172     red tower
# 4              3  1635574102  9781635574104    bloomsbury
#
#                        title          author        contributor
# 0                  the women  kristin hannah  by kristin hannah
# 1                fourth wing  rebecca yarros  by rebecca yarros
# 2                      bride   ali hazelwood   by ali hazelwood
# 3                 iron flame  rebecca yarros  by rebecca yarros
# 4  house of flame and shadow   sarah j. maas   by sarah j. maas

# %% [markdown]
# ## Step 4
# Change datatype of bestsellers_date to datetime. Change datatype of isbn13 to numeric.

# %%
df["isbn13"] = pd.to_numeric(df["isbn13"], errors= "coerce")
df["bestsellers_date"] = pd.to_datetime(df["bestsellers_date"])
df.dtypes
# Out:
# bestsellers_date    datetime64[ns]
# bestsellers_list            object
# rank                         int64
# rank_last_week               int64
# weeks_on_list                int64
# isbn10                      object
# isbn13                     float64
# publisher                   object
# title                       object
# author                      object
# contributor                 object
# dtype: object

# %% [markdown]
# ## Step 5
# Strip "by" from contributor. keep only first listed author as primary author in "author" column. All others will remain only in "contributor". Replace "and"/"with" to "/" in "contributor" column, to match format from CSV data.

# %%
df['contributor'] = df['contributor'].str.replace('by', '')

# %%
new = df["author"].str.split("and", n = 1, expand = True)
df["first_listed_author"] = new[0]
df.drop(columns = ["author"], inplace = True)

# %%
df['contributor'] = df['contributor'].str.replace('with', '/')
df['contributor'] = df['contributor'].str.replace('and', '/')
df.head()
# Out:
#   bestsellers_date                   bestsellers_list  rank  rank_last_week  \
# 0       2024-02-17  combined print and e-book fiction     1               1
# 1       2024-02-17  combined print and e-book fiction     2               5
# 2       2024-02-17  combined print and e-book fiction     3               4
# 3       2024-02-17  combined print and e-book fiction     4               6
# 4       2024-02-17  combined print and e-book fiction     5               3
#
#    weeks_on_list      isbn10        isbn13     publisher  \
# 0              2  1250178630  9.781250e+12  st. martin's
# 1             42  1649374046  9.781649e+12     red tower
# 2              2  0593550404  9.780594e+12       berkley
# 3             15  1649374178  9.781649e+12     red tower
# 4              3  1635574102  9.781636e+12    bloomsbury
#
#                        title      contributor first_listed_author
# 0                  the women   kristin hannah      kristin hannah
# 1                fourth wing   rebecca yarros      rebecca yarros
# 2                      bride    ali hazelwood       ali hazelwood
# 3                 iron flame   rebecca yarros      rebecca yarros
# 4  house of flame and shadow    sarah j. maas       sarah j. maas

# %% [markdown]
# ## Step 6
# Change order of dataframe to be more easily read.

# %%
# rearrange dataframe column order
df = df.iloc[:,[8,10,9,5,6,1,2,3,4,0,7]]

# %%
df.to_csv("api_data.csv", index = False)

# %% [markdown]
# ## Ethical Implications

# %% [markdown]
# Even though there were duplicates within the datset, upon investigation I did not remove any of the duplicates because they either represented different versions of the same title (i.e. hardcover, paperback, audiobook, or ebook) which each corresponds to a different ISBN. However, even for titles that had the same ISBN and version, if they appeared on different bestseller's list I still kept them as seperate entities because while it would be straightforward if the dataset only included the bestseller's lists the title appears on, it becomes much more complicated to contain several different values for rank, weeks_on_list, and rank_last_week. Removing all authors except the first listed from the authors column presents an interesting dilemna: ultimately, the choice was made to simplify the column at the risk of undervaluing some authors' contributions to the title presented by excluding them from the author column and delegating them to the contributor column only. This also presents problems when titles are co-written, or are a collection of stories and the author column would imply that the author listed first is the primary contributor; therefore, "author" becomes "first_listed_author" to maintain that transparency clearly in the final dataset.

# %% [markdown]
# ## Readable Dataset

# %%
print(df.head(60))
# Out:
#                                           title  \
# 0                                     the women
# 1                                   fourth wing
# 2                                         bride
# 3                                    iron flame
# 4                     house of flame and shadow
# 5                                    crosshairs
# 6                                   the teacher
# 7              the heaven & earth grocery store
# 8                      house of earth and blood
# 9                      a court of silver flames
# 10                                   icebreaker
# 11                                the housemaid
# 12                               first lie wins
# 13                                 fangirl down
# 14                      house of sky and breath
# 15                   killers of the flower moon
# 16                                    the wager
# 17                     the body keeps the score
# 18                         the boys in the boat
# 19                                      outlive
# 20                               capote's women
# 21                              medgar & myrlie
# 22                               oath and honor
# 23                                        caste
# 24                 everything i know about love
# 25                           masters of the air
# 26                               all about love
# 27                             life after power
# 28                                    elon musk
# 29                           what have we here?
# 30                                    the women
# 31                                  fourth wing
# 32                                   iron flame
# 33                    house of flame and shadow
# 34             the heaven & earth grocery store
# 35                               first lie wins
# 36                                   crosshairs
# 37                         lessons in chemistry
# 38                                    gothikana
# 39                         what feasts at night
# 40                  remarkably bright creatures
# 41                                     the fury
# 42                             demon copperhead
# 43                        the covenant of water
# 44                                     tom lake
# 45                                    the wager
# 46                                      outlive
# 47                              medgar & myrlie
# 48                               oath and honor
# 49                           what have we here?
# 50                              the woman in me
# 51  friends, lovers, and the big terrible thing
# 52                         i'm glad my mom died
# 53                             life after power
# 54                                    elon musk
# 55                                    the grift
# 56                     the pursuit of happiness
# 57        the kingdom, the power, and the glory
# 58                                     the lede
# 59             hits, flops, and other illusions
#
#               first_listed_author                       contributor  \
# 0                  kristin hannah                    kristin hannah
# 1                  rebecca yarros                    rebecca yarros
# 2                   ali hazelwood                     ali hazelwood
# 3                  rebecca yarros                    rebecca yarros
# 4                   sarah j. maas                     sarah j. maas
# 5                james patterson    james patterson / james o. born
# 6                 freida mcfadden                   freida mcfadden
# 7                   james mcbride                     james mcbride
# 8                   sarah j. maas                     sarah j. maas
# 9                   sarah j. maas                     sarah j. maas
# 10                   hannah grace                      hannah grace
# 11                freida mcfadden                   freida mcfadden
# 12                  ashley elston                     ashley elston
# 13                   tessa bailey                      tessa bailey
# 14                  sarah j. maas                     sarah j. maas
# 15                    david grann                       david grann
# 16                    david grann                       david grann
# 17            bessel van der kolk               bessel van der kolk
# 18             daniel james brown                daniel james brown
# 19  peter attia with bill gifford        peter attia / bill gifford
# 20                laurence leamer                   laurence leamer
# 21                   joy-ann reid                      joy-ann reid
# 22                     liz cheney                        liz cheney
# 23               isabel wilkerson                  isabel wilkerson
# 24                 dolly alderton                    dolly alderton
# 25               donald l. miller                  donald l. miller
# 26                     bell hooks                        bell hooks
# 27                    jared cohen                       jared cohen
# 28                walter isaacson                   walter isaacson
# 29             billy dee williams                billy dee williams
# 30                 kristin hannah                    kristin hannah
# 31                 rebecca yarros                    rebecca yarros
# 32                 rebecca yarros                    rebecca yarros
# 33                  sarah j. maas                     sarah j. maas
# 34                  james mcbride                     james mcbride
# 35                  ashley elston                     ashley elston
# 36               james patterson    james patterson / james o. born
# 37                  bonnie garmus                     bonnie garmus
# 38                          runyx                             runyx
# 39                  t. kingfisher                     t. kingfisher
# 40                  shel van pelt                     shel van pelt
# 41               alex michaelides                  alex michaelides
# 42             barbara kingsolver                barbara kingsolver
# 43               abraham verghese                  abraham verghese
# 44                   ann patchett                      ann patchett
# 45                    david grann                       david grann
# 46  peter attia with bill gifford        peter attia / bill gifford
# 47                   joy-ann reid                      joy-ann reid
# 48                     liz cheney                        liz cheney
# 49             billy dee williams                billy dee williams
# 50                 britney spears                    britney spears
# 51                  matthew perry                     matthew perry
# 52               jennette mccurdy                  jennette mccurdy
# 53                    jared cohen                       jared cohen
# 54                walter isaacson                   walter isaacson
# 55                      clay cane                         clay cane
# 56                  jeffrey rosen                     jeffrey rosen
# 57                    tim alberta                       tim alberta
# 58                 calvin trillin                    calvin trillin
# 59                       ed zwick                          ed zwick
#
#         isbn10        isbn13                      bestsellers_list  rank  \
# 0   1250178630  9.781250e+12     combined print and e-book fiction     1
# 1   1649374046  9.781649e+12     combined print and e-book fiction     2
# 2   0593550404  9.780594e+12     combined print and e-book fiction     3
# 3   1649374178  9.781649e+12     combined print and e-book fiction     4
# 4   1635574102  9.781636e+12     combined print and e-book fiction     5
# 5   031640358x  9.780316e+12     combined print and e-book fiction     6
# 6   1728296218  9.781728e+12     combined print and e-book fiction     7
# 7   0593422945  9.780593e+12     combined print and e-book fiction     8
# 8   1635577020  9.781636e+12     combined print and e-book fiction     9
# 9   1635577993  9.781636e+12     combined print and e-book fiction    10
# 10  1668026031  9.781668e+12     combined print and e-book fiction    11
# 11  1538742578  9.781539e+12     combined print and e-book fiction    12
# 12  0593492919  9.780593e+12     combined print and e-book fiction    13
# 13  0063308363  9.780063e+12     combined print and e-book fiction    14
# 14        none  9.781636e+12     combined print and e-book fiction    15
# 15  0307742482  9.780308e+12  combined print and e-book nonfiction     1
# 16  0385534264  9.780386e+12  combined print and e-book nonfiction     2
# 17  0143127748  9.780143e+12  combined print and e-book nonfiction     3
# 18  0143125478  9.780143e+12  combined print and e-book nonfiction     4
# 19  0593236599  9.780593e+12  combined print and e-book nonfiction     5
# 20  0593328094  9.780593e+12  combined print and e-book nonfiction     6
# 21  0063068796  9.780063e+12  combined print and e-book nonfiction     7
# 22  0316572063  9.780317e+12  combined print and e-book nonfiction     8
# 23  0593230272  9.780593e+12  combined print and e-book nonfiction     9
# 24  0062968793  9.780063e+12  combined print and e-book nonfiction    10
# 25  0743235452  9.780743e+12  combined print and e-book nonfiction    11
# 26  0060959479  9.780061e+12  combined print and e-book nonfiction    12
# 27  1982154543  9.781982e+12  combined print and e-book nonfiction    13
# 28  1982181281  9.781982e+12  combined print and e-book nonfiction    14
# 29        none  9.780594e+12  combined print and e-book nonfiction    15
# 30  1250178630  9.781250e+12                     hardcover fiction     1
# 31  1649374046  9.781649e+12                     hardcover fiction     2
# 32  1649374178  9.781649e+12                     hardcover fiction     3
# 33  1635574102  9.781636e+12                     hardcover fiction     4
# 34  0593422945  9.780593e+12                     hardcover fiction     5
# 35  0593492919  9.780593e+12                     hardcover fiction     6
# 36  0316403385  9.780316e+12                     hardcover fiction     7
# 37  038554734x  9.780386e+12                     hardcover fiction     8
# 38  1250334209  9.781250e+12                     hardcover fiction     9
# 39  1250830850  9.781251e+12                     hardcover fiction    10
# 40  0063204150  9.780063e+12                     hardcover fiction    11
# 41  125075898x  9.781251e+12                     hardcover fiction    12
# 42  0063251922  9.780063e+12                     hardcover fiction    13
# 43  0802162177  9.780802e+12                     hardcover fiction    14
# 44  006332752x  9.780063e+12                     hardcover fiction    15
# 45  0385534264  9.780386e+12                  hardcover nonfiction     1
# 46  0593236599  9.780593e+12                  hardcover nonfiction     2
# 47  0063068796  9.780063e+12                  hardcover nonfiction     3
# 48  0316572063  9.780317e+12                  hardcover nonfiction     4
# 49        none  9.780594e+12                  hardcover nonfiction     5
# 50  1668009048  9.781668e+12                  hardcover nonfiction     6
# 51  1250866448  9.781251e+12                  hardcover nonfiction     7
# 52  1982185821  9.781982e+12                  hardcover nonfiction     8
# 53  1982154543  9.781982e+12                  hardcover nonfiction     9
# 54  1982181281  9.781982e+12                  hardcover nonfiction    10
# 55  1728290228  9.781728e+12                  hardcover nonfiction    11
# 56  1668002477  9.781668e+12                  hardcover nonfiction    12
# 57  006322688x  9.780063e+12                  hardcover nonfiction    13
# 58  0593596447  9.780594e+12                  hardcover nonfiction    14
# 59  1668046997  9.781668e+12                  hardcover nonfiction    15
#
#     rank_last_week  weeks_on_list bestsellers_date         publisher
# 0                1              2       2024-02-17      st. martin's
# 1                5             42       2024-02-17         red tower
# 2                4              2       2024-02-17           berkley
# 3                6             15       2024-02-17         red tower
# 4                3              3       2024-02-17        bloomsbury
# 5                0              1       2024-02-17     little, brown
# 6                2              2       2024-02-17      poisoned pen
# 7                8             16       2024-02-17         riverhead
# 8                7             12       2024-02-17        bloomsbury
# 9               12             12       2024-02-17        bloomsbury
# 10              13             35       2024-02-17             atria
# 11              10             35       2024-02-17     grand central
# 12              11              7       2024-02-17     pamela dorman
# 13               0              1       2024-02-17              avon
# 14              14             11       2024-02-17        bloomsbury
# 15               1            116       2024-02-17         doubleday
# 16               3             43       2024-02-17         doubleday
# 17               2            181       2024-02-17           penguin
# 18               4            132       2024-02-17           penguin
# 19               6             47       2024-02-17           harmony
# 20               9              3       2024-02-17            putnam
# 21               5              2       2024-02-17           mariner
# 22               8             11       2024-02-17     little, brown
# 23               7             66       2024-02-17      random house
# 24              12             13       2024-02-17  harper perennial
# 25              10              3       2024-02-17  simon & schuster
# 26              13             60       2024-02-17            morrow
# 27               0              1       2024-02-17  simon & schuster
# 28              15             21       2024-02-17  simon & schuster
# 29               0              1       2024-02-17             knopf
# 30               1              2       2024-02-17      st. martin's
# 31               3             41       2024-02-17         red tower
# 32               4             15       2024-02-17         red tower
# 33               2              3       2024-02-17        bloomsbury
# 34               5             26       2024-02-17         riverhead
# 35               6              7       2024-02-17     pamela dorman
# 36               0              1       2024-02-17     little, brown
# 37               7             93       2024-02-17         doubleday
# 38               9              4       2024-02-17           bramble
# 39               0              1       2024-02-17     tor nightfire
# 40              10             38       2024-02-17              ecco
# 41               8              5       2024-02-17           celadon
# 42              11             68       2024-02-17            harper
# 43              14             37       2024-02-17             grove
# 44               0             24       2024-02-17            harper
# 45               2             43       2024-02-17         doubleday
# 46               3             47       2024-02-17           harmony
# 47               1              2       2024-02-17           mariner
# 48               4             11       2024-02-17     little, brown
# 49               0              1       2024-02-17             knopf
# 50               5             17       2024-02-17           gallery
# 51               6             32       2024-02-17          flatiron
# 52              13             71       2024-02-17  simon & schuster
# 53               0              1       2024-02-17  simon & schuster
# 54               8             23       2024-02-17  simon & schuster
# 55               7              3       2024-02-17       sourcebooks
# 56               0              1       2024-02-17  simon & schuster
# 57               9              9       2024-02-17            harper
# 58               0              1       2024-02-17      random house
# 59               0              1       2024-02-17           gallery

# %%
print(df.tail(60))
# Out:
#                                     title  \
# 625                          born a crime
# 626                        hidden figures
# 627              between the world and me
# 628                      the new jim crow
# 629                            just mercy
# 630                         march trilogy
# 631                       march: book one
# 632   misadventures of awkward black girl
# 633               you can't touch my hair
# 634            stamped from the beginning
# 635                                shaken
# 636                       the book of joy
# 637             think better, live better
# 638                   the four agreements
# 639                             uninvited
# 640                        the broken way
# 641                 the book of mysteries
# 642                  present over perfect
# 643                      the power of now
# 644                  the american miracle
# 645                               sapiens
# 646              the body keeps the score
# 647                          being mortal
# 648               thinking, fast and slow
# 649                          the mosquito
# 650  the immortal life of henrietta lacks
# 651                              dopesick
# 652                          why we sleep
# 653       21 lessons for the 21st century
# 654                                 quiet
# 655                                 range
# 656                              shoe dog
# 657                         the sixth man
# 658                  the boys in the boat
# 659                          never settle
# 660                              wolfpack
# 661                        barbarian days
# 662             if these walls could talk
# 663              for the good of the game
# 664                           all the way
# 665                         atlas obscura
# 666           humans of new york: stories
# 667          the road to little dribbling
# 668                    humans of new york
# 669                                 sully
# 670            destinations of a lifetime
# 671                     speaking american
# 672                                  wild
# 673                                  lion
# 674                    nonstop metropolis
# 675                if he had been with me
# 676                better than the movies
# 677                 a thousand boy kisses
# 678                        girl in pieces
# 679                    that's not my name
# 680                          check & mate
# 681                             lightlark
# 682                           the do-over
# 683          my life with the walter boys
# 684                        the book thief
#
#                                 first_listed_author  \
# 625                                     trevor noah
# 626                            margot lee shetterly
# 627                                ta-nehisi coates
# 628                                   michelle alex
# 629                                 bryan stevenson
# 630                                     john lewis
# 631                                     john lewis
# 632                                        issa rae
# 633                                 phoebe robinson
# 634                                   ibram x kendi
# 635                                       tim tebow
# 636                                 the dalai lama
# 637                                     joel osteen
# 638                                 don miguel ruiz
# 639                                  lysa terkeurst
# 640                                     ann voskamp
# 641                                   jonathan cahn
# 642                                 shauna niequist
# 643                                   eckhart tolle
# 644                                  michael medved
# 645                               yuval noah harari
# 646                             bessel van der kolk
# 647                                        atul gaw
# 648                                 daniel kahneman
# 649                              timothy c winegard
# 650                                  rebecca skloot
# 651                                       beth macy
# 652                                  matthew walker
# 653                               yuval noah harari
# 654                                      susan cain
# 655                                   david epstein
# 656                                     phil knight
# 657
# 658                              daniel james brown
# 659                                     marty smith
# 660                                      ab wambach
# 661                                william finnegan
# 662                                     jerry remy
# 663                      bud selig with phil rogers
# 664                  joe namath with sean mortimer
# 665                      joshua foer, dylan thuras
# 666                                              br
# 667                                     bill bryson
# 668                                              br
# 669  chesley b sullenberger iii with jeffrey zaslow
# 670                the staff of national geographic
# 671                                       josh katz
# 672                                  cheryl strayed
# 673                                  saroo brierley
# 674                                 rebecca solnit
# 675                                    laura nowlin
# 676                                    lynn painter
# 677                                     tillie cole
# 678                                kathleen glasgow
# 679                                     megan lally
# 680                                   ali hazelwood
# 681                                      alex aster
# 682                                    lynn painter
# 683                                       ali novak
# 684                                    markus zusak
#
#                                            contributor      isbn10  \
# 625                                        trevor noah  0399588175
# 626                               margot lee shetterly  0062363603
# 627                                   ta-nehisi coates  0812993543
# 628                                   michelle alex/er  1595586431
# 629                                    bryan stevenson  081298496x
# 630   john lewis / /rew aydin. illustrated  nate po...  1603093958
# 631   john lewis / /rew aydin. illustrated  nate po...  1603093001
# 632                                           issa rae  1476749094
# 633                                    phoebe robinson  0143129201
# 634                                     ibram x. kendi  1568584636
# 635                                          tim tebow  0735289867
# 636     the dalai lama / desmond tutu / douglas abrams  0399185046
# 637                                        joel osteen  0892969679
# 638                                    don miguel ruiz  1878424319
# 639                                     lysa terkeurst  1400205875
# 640                                        ann voskamp  0310318580
# 641                                      jonathan cahn  162998941x
# 642                                    shauna niequist  0310342996
# 643                                      eckhart tolle  1577314808
# 644                                     michael medved  0553447262
# 645                                  yuval noah harari  0062316117
# 646                                bessel van der kolk  0143127748
# 647                                         atul gaw/e  1250076226
# 648                                    daniel kahneman  0374533555
# 649                                timothy c. winegard  1524743410
# 650                                     rebecca skloot  1400052181
# 651                                          beth macy  0316551309
# 652                                     matthew walker  1501144324
# 653                                  yuval noah harari  0525512195
# 654                                         susan cain  0307352153
